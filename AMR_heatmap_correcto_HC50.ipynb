# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
SEROTIPOS = ['Typhimurium', 'Newport', 'Enteritidis', 'Infantis', 'I 1,4,[5],12:i:-', 'Agona']

entero_base = pd.read_csv(os.path.join("out", "Salmonella_Chile_201124_filt.tsv"), sep='\t')
entero_base = entero_base[entero_base['SISTR1 Serovar'].isin(SEROTIPOS)]

entero_base['HC50'] = entero_base['HC50'].astype(str)
entero_base['SISTR1 Serovar HC50'] = entero_base['SISTR1 Serovar'] + " " + entero_base['HC50']
entero_base = entero_base.drop_duplicates(subset=['Assembly Barcode'])
# Cuento los genomas del HC
entero_base = entero_base['SISTR1 Serovar HC50'].value_counts().reset_index()
entero_base = entero_base.rename(columns={'SISTR1 Serovar HC50': 'Counts', 'index': 'SISTR1 Serovar HC50'})
entero_base.to_csv("out/entero_base_count.tsv", index=False, sep='\t')
entero_base_count = entero_base.set_index('SISTR1 Serovar HC50')
entero_base_count
# Out:
#                      Counts
# SISTR1 Serovar HC50
# Infantis 36             230
# Enteritidis 87           85
# Typhimurium 158          30
# Agona 29                 30
# Typhimurium 2340         14
# Typhimurium 5196         13
# Newport 938              13
# Typhimurium 293          10
# Infantis 2398             9
# Typhimurium 305           8
# Typhimurium 2             8
# Typhimurium 269           6
# I 1,4,[5],12:i:- 2        5
# Newport 302268            5
# I 1,4,[5],12:i:- 48       4
# Enteritidis 12            3
# Typhimurium 147           3
# Newport 302252            2
# Typhimurium 1950          2
# Newport 147611            1
# Typhimurium 235           1
# Enteritidis 397           1
# Newport 323862            1
# Newport 323722            1
# Typhimurium 92            1
# Newport 10355             1
# Typhimurium 1585          1
# Agona 147593              1
# Newport 17481             1
# Newport 48062             1

# %%
df = pd.read_csv(os.path.join("db", "AMR_raw_output_file.tsv"), sep='\t')
#print(df.columns)
df = df[['Name', 'Element symbol', 'Type', 'Class']]
# Quitar headers
df = df[df['Name'] != 'Name']
## Cambio valores nombres por assemblies barcode
df = df.rename(columns={'Name': 'Assembly Barcode', 'Element symbol': 'Resistance gene'})
df['Assembly Barcode'] = df['Assembly Barcode'].str.replace(r'(\..*)', '', regex=True)
### Merge
data = pd.read_csv(os.path.join("out", "Salmonella_Chile_201124_filt.tsv"), sep='\t')
db = pd.merge(df, data, on='Assembly Barcode', how='left').reset_index(drop=True)
db = db.set_index('Assembly Barcode')
db
# Out:
#                  Resistance gene       Type                Class  \
# Assembly Barcode
# SAL_IA5729AA_AS             sinH  VIRULENCE                  NaN
# SAL_IA5729AA_AS             sul1        AMR          SULFONAMIDE
# SAL_IA5729AA_AS       qacEdelta1     STRESS  QUATERNARY AMMONIUM
# SAL_IA5729AA_AS             mdsB        AMR               EFFLUX
# SAL_IA5729AA_AS             mdsA        AMR               EFFLUX
# ...                          ...        ...                  ...
# SAL_RD3120AA_AS             golS     STRESS                 GOLD
# SAL_RD3120AA_AS             golT     STRESS          COPPER/GOLD
# SAL_RD3120AA_AS             mdsA        AMR               EFFLUX
# SAL_RD3120AA_AS             mdsB        AMR               EFFLUX
# SAL_RD3120AA_AS        gyrA_D87Y        AMR            QUINOLONE
#
#                  SISTR1 Serovar  HC20  HC50 Source Niche  Collection Year
# Assembly Barcode
# SAL_IA5729AA_AS     Typhimurium   305   305    Livestock             2006
# SAL_IA5729AA_AS     Typhimurium   305   305    Livestock             2006
# SAL_IA5729AA_AS     Typhimurium   305   305    Livestock             2006
# SAL_IA5729AA_AS     Typhimurium   305   305    Livestock             2006
# SAL_IA5729AA_AS     Typhimurium   305   305    Livestock             2006
# ...                         ...   ...   ...          ...              ...
# SAL_RD3120AA_AS        Infantis   343    36         Food             2024
# SAL_RD3120AA_AS        Infantis   343    36         Food             2024
# SAL_RD3120AA_AS        Infantis   343    36         Food             2024
# SAL_RD3120AA_AS        Infantis   343    36         Food             2024
# SAL_RD3120AA_AS        Infantis   343    36         Food             2024
#
# [15879 rows x 8 columns]

# %%
"""
Filtros: solo AMR, ignorar mdsA y mdsB
"""
solo_AMR = db[db['Type'] == 'AMR']
amr = solo_AMR.drop(columns=['Type'])
amr = amr[amr['Resistance gene'] != 'mdsA']
amr = amr[amr['Resistance gene'] != 'mdsB']
print(f"Total AMR: {amr.shape[0]}")
amr['HC20'] = amr['HC20'].astype(str)
amr['SISTR1 Serovar HC20'] = amr['SISTR1 Serovar'] + " " + amr['HC20']
amr = amr.sort_values(by='SISTR1 Serovar HC20')
amr['HC50'] = amr['HC50'].astype(str)
amr['SISTR1 Serovar HC50'] = amr['SISTR1 Serovar'] + " " + amr['HC50']
amr = amr.sort_values(by='SISTR1 Serovar HC50')
amr
# Out:
# Total AMR: 2155
#                  Resistance gene           Class SISTR1 Serovar    HC20  HC50  \
# Assembly Barcode
# SAL_AD8849AA_AS             floR        PHENICOL       Adelaide  302263  2895
# SAL_AD8849AA_AS         blaTEM-1     BETA-LACTAM       Adelaide  302263  2895
# SAL_AD8849AA_AS           dfrA12    TRIMETHOPRIM       Adelaide  302263  2895
# SAL_AD8849AA_AS            aadA2  AMINOGLYCOSIDE       Adelaide  302263  2895
# SAL_AD8849AA_AS             sul1     SULFONAMIDE       Adelaide  302263  2895
# ...                          ...             ...            ...     ...   ...
# SAL_DC0019AA_AS        blaCARB-2     BETA-LACTAM    Typhimurium     305   305
# SAL_DC0019AA_AS             sul1     SULFONAMIDE    Typhimurium     305   305
# SAL_DC0019AA_AS            aadA2  AMINOGLYCOSIDE    Typhimurium     305   305
# SAL_OC0804AA_AS           tet(G)    TETRACYCLINE    Typhimurium     305   305
# SAL_DC9664AA_AS             qnrB       QUINOLONE    Worthington  147475    35
#
#                  Source Niche  Collection Year SISTR1 Serovar HC20  \
# Assembly Barcode
# SAL_AD8849AA_AS   Environment             2022     Adelaide 302263
# SAL_AD8849AA_AS   Environment             2022     Adelaide 302263
# SAL_AD8849AA_AS   Environment             2022     Adelaide 302263
# SAL_AD8849AA_AS   Environment             2022     Adelaide 302263
# SAL_AD8849AA_AS   Environment             2022     Adelaide 302263
# ...                       ...              ...                 ...
# SAL_DC0019AA_AS   Environment             2019     Typhimurium 305
# SAL_DC0019AA_AS   Environment             2019     Typhimurium 305
# SAL_DC0019AA_AS   Environment             2019     Typhimurium 305
# SAL_OC0804AA_AS   Environment             2019     Typhimurium 305
# SAL_DC9664AA_AS   Environment             2019  Worthington 147475
#
#                  SISTR1 Serovar HC50
# Assembly Barcode
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_AD8849AA_AS        Adelaide 2895
# ...                              ...
# SAL_DC0019AA_AS      Typhimurium 305
# SAL_DC0019AA_AS      Typhimurium 305
# SAL_DC0019AA_AS      Typhimurium 305
# SAL_OC0804AA_AS      Typhimurium 305
# SAL_DC9664AA_AS       Worthington 35
#
# [2155 rows x 9 columns]

# %%
SEROTIPOS = ['Typhimurium', 'Newport', 'Enteritidis', 'Infantis', 'I 1,4,[5],12:i:-', 'Agona']

# %%
"""
Filtros: amr solo de familias de importancia
"""
FAMILIAS = ['QUINOLONE', 'BETA-LACTAM', 'MACROLIDE', 'TRIMETHOPRIM']
amr_de_importancia = amr[amr['Class'].isin(FAMILIAS)]
amr_de_importancia_todos_genomas = amr_de_importancia.sort_values(by='SISTR1 Serovar HC20')
print(f"Total AMR relevantes: {amr_de_importancia_todos_genomas.shape[0]}")
amr_de_importancia_todos_genomas.head(30)
# Out:
# Total AMR relevantes: 598
#                  Resistance gene         Class SISTR1 Serovar    HC20   HC50  \
# Assembly Barcode
# SAL_AD8849AA_AS         blaTEM-1   BETA-LACTAM       Adelaide  302263   2895
# SAL_AD8849AA_AS           dfrA12  TRIMETHOPRIM       Adelaide  302263   2895
# SAL_QD2199AA_AS         blaTEM-1   BETA-LACTAM          Agona     419     29
# SAL_QD2199AA_AS            qnrS1     QUINOLONE          Agona     419     29
# SAL_ZC7016AA_AS           dfrA17  TRIMETHOPRIM          Agona     419     29
# SAL_JC3732AA_AS         blaTEM-1   BETA-LACTAM          Agona     419     29
# SAL_DC0057AA_AS         blaTEM-1   BETA-LACTAM          Agona     419     29
# SAL_JC3732AA_AS           dfrA14  TRIMETHOPRIM          Agona     419     29
# SAL_DC0057AA_AS           dfrA14  TRIMETHOPRIM          Agona     419     29
# SAL_PD3883AA_AS      blaCTX-M-65   BETA-LACTAM         Amager   35565   1458
# SAL_YC3231AA_AS           qnrB19     QUINOLONE     Braenderup  302754    185
# SAL_TC9673AA_AS           qnrB19     QUINOLONE     Braenderup  302754    185
# SAL_FB0409AA_AS           qnrB19     QUINOLONE    Brandenburg  147609  51313
# SAL_VB0071AA_AS           qnrB19     QUINOLONE    Brandenburg  147609  51313
# SAL_AD8864AA_AS           qnrB19     QUINOLONE    Brandenburg  147609  51313
# SAL_TC9676AA_AS           qnrB19     QUINOLONE          Cerro      40     40
# SAL_VB2035AA_AS           qnrB19     QUINOLONE          Cerro      40     40
# SAL_YC3142AA_AS        blaROB-11   BETA-LACTAM          Cerro      40     40
# SAL_YC3142AA_AS             estT     MACROLIDE          Cerro      40     40
# SAL_YC3142AA_AS         blaTEM-1   BETA-LACTAM          Cerro      40     40
# SAL_TC9627AA_AS           qnrB19     QUINOLONE      Corvallis  302774     70
# SAL_MB2491AA_AS            qnrS1     QUINOLONE      Corvallis      70     70
# SAL_PD2976AA_AS           qnrB19     QUINOLONE      Corvallis   71514     70
# SAL_AD9205AA_AS           qnrB19     QUINOLONE      Corvallis   71514     70
# SAL_DC0023AA_AS           qnrB19     QUINOLONE      Corvallis   71514     70
# SAL_XC6776AA_AS         blaTEM-1   BETA-LACTAM          Derby    4180   4180
# SAL_XC6776AA_AS           mph(A)     MACROLIDE          Derby    4180   4180
# SAL_PD2829AA_AS           qnrB19     QUINOLONE          Derby  465237      3
# SAL_PD2829AA_AS         blaTEM-1   BETA-LACTAM          Derby  465237      3
# SAL_YC2751AA_AS        gyrA_D87Y     QUINOLONE    Enteritidis     397    397
#
#                       Source Niche  Collection Year SISTR1 Serovar HC20  \
# Assembly Barcode
# SAL_AD8849AA_AS        Environment             2022     Adelaide 302263
# SAL_AD8849AA_AS        Environment             2022     Adelaide 302263
# SAL_QD2199AA_AS        Environment             2022           Agona 419
# SAL_QD2199AA_AS        Environment             2022           Agona 419
# SAL_ZC7016AA_AS   Companion Animal             2021           Agona 419
# SAL_JC3732AA_AS               Food             2018           Agona 419
# SAL_DC0057AA_AS        Environment             2019           Agona 419
# SAL_JC3732AA_AS               Food             2018           Agona 419
# SAL_DC0057AA_AS        Environment             2019           Agona 419
# SAL_PD3883AA_AS        Environment             2023        Amager 35565
# SAL_YC3231AA_AS        Environment             2022   Braenderup 302754
# SAL_TC9673AA_AS        Environment             2019   Braenderup 302754
# SAL_FB0409AA_AS        Environment             2013  Brandenburg 147609
# SAL_VB0071AA_AS        Environment             2019  Brandenburg 147609
# SAL_AD8864AA_AS        Environment             2021  Brandenburg 147609
# SAL_TC9676AA_AS        Environment             2020            Cerro 40
# SAL_VB2035AA_AS        Environment             2019            Cerro 40
# SAL_YC3142AA_AS        Environment             2019            Cerro 40
# SAL_YC3142AA_AS        Environment             2019            Cerro 40
# SAL_YC3142AA_AS        Environment             2019            Cerro 40
# SAL_TC9627AA_AS        Environment             2020    Corvallis 302774
# SAL_MB2491AA_AS        Environment             2016        Corvallis 70
# SAL_PD2976AA_AS        Environment             2022     Corvallis 71514
# SAL_AD9205AA_AS        Environment             2021     Corvallis 71514
# SAL_DC0023AA_AS        Environment             2019     Corvallis 71514
# SAL_XC6776AA_AS        Environment             2021          Derby 4180
# SAL_XC6776AA_AS        Environment             2021          Derby 4180
# SAL_PD2829AA_AS        Environment             2023        Derby 465237
# SAL_PD2829AA_AS        Environment             2023        Derby 465237
# SAL_YC2751AA_AS        Environment             2021     Enteritidis 397
#
#                  SISTR1 Serovar HC50
# Assembly Barcode
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_QD2199AA_AS             Agona 29
# SAL_QD2199AA_AS             Agona 29
# SAL_ZC7016AA_AS             Agona 29
# SAL_JC3732AA_AS             Agona 29
# SAL_DC0057AA_AS             Agona 29
# SAL_JC3732AA_AS             Agona 29
# SAL_DC0057AA_AS             Agona 29
# SAL_PD3883AA_AS          Amager 1458
# SAL_YC3231AA_AS       Braenderup 185
# SAL_TC9673AA_AS       Braenderup 185
# SAL_FB0409AA_AS    Brandenburg 51313
# SAL_VB0071AA_AS    Brandenburg 51313
# SAL_AD8864AA_AS    Brandenburg 51313
# SAL_TC9676AA_AS             Cerro 40
# SAL_VB2035AA_AS             Cerro 40
# SAL_YC3142AA_AS             Cerro 40
# SAL_YC3142AA_AS             Cerro 40
# SAL_YC3142AA_AS             Cerro 40
# SAL_TC9627AA_AS         Corvallis 70
# SAL_MB2491AA_AS         Corvallis 70
# SAL_PD2976AA_AS         Corvallis 70
# SAL_AD9205AA_AS         Corvallis 70
# SAL_DC0023AA_AS         Corvallis 70
# SAL_XC6776AA_AS           Derby 4180
# SAL_XC6776AA_AS           Derby 4180
# SAL_PD2829AA_AS              Derby 3
# SAL_PD2829AA_AS              Derby 3
# SAL_YC2751AA_AS      Enteritidis 397

# %% [markdown]
# ### Heatmap

# %%
def make_matrix(df, HC: str):
    amr_matrix = df.groupby([f'SISTR1 Serovar {HC}', 'Resistance gene']).size().unstack(fill_value=0)
    tipo_familia_dict = dict(zip(df['Resistance gene'], df['Class']))
    sorted_columns = sorted(amr_matrix.columns, key=lambda x: (tipo_familia_dict.get(x, ''), x))
    matrix = amr_matrix[sorted_columns]
    ## mono de Typhimurium
    mono = ['I 1,4,[5],12:i:- 2']
    new_sort = [idx for idx in matrix.index if idx not in mono] + mono
    matrix = matrix.reindex(new_sort)
    ## mv floR
    #floR = ['floR']
    #new_sort = [col for col in matrix.columns if col not in floR] + floR
    return matrix

# %% [markdown]
# ### Plots

# %%
"""
Mapa de calor, porcentaje AMR en cluster HC de importancia
"""
HC = 'HC50'
amr_de_importancia_filtrado = amr_de_importancia_todos_genomas[amr_de_importancia_todos_genomas['SISTR1 Serovar'].isin(SEROTIPOS)]
arm_matrix_todos_los_genomas = make_matrix(amr_de_importancia_filtrado, HC)
gen_de_importancia = arm_matrix_todos_los_genomas
divisors = entero_base_count['Counts'].replace(0, np.nan)
arm_matrix_todos_los_genomas = arm_matrix_todos_los_genomas.div(divisors, axis=0)
arm_matrix_todos_los_genomas_final = arm_matrix_todos_los_genomas.fillna(0)

arm_matrix_filtrado = arm_matrix_todos_los_genomas_final.loc[~(arm_matrix_todos_los_genomas_final==0).all(axis=1)]
heat_map = arm_matrix_filtrado.apply(lambda x: (x * 100).astype(int), axis=1)
plt.figure(figsize=(12, 8))
ax = sns.heatmap(heat_map, cmap="Greens", cbar=False, linecolor='#d5fcd4', square=True, annot=heat_map, fmt="d", annot_kws={"size": 8})

plt.xticks(rotation=45, ha='right')
plt.xlabel('')

plt.tight_layout()
plt.savefig(f'presentacion-img/heatmap_porcentaje_{HC}_de_importancia_con_al_menos_un_AMR.png', format='png', dpi=900, bbox_inches='tight')
plt.show()

# %%
HC = 'HC20'
SEROTIPOS = ['Typhimurium', 'Newport', 'Enteritidis', 'Infantis', 'I 1,4,[5],12:i:-', 'Agona']

entero_base = pd.read_csv(os.path.join("out", "Salmonella_Chile_201124_filt.tsv"), sep='\t')
entero_base = entero_base[entero_base['SISTR1 Serovar'].isin(SEROTIPOS)]

entero_base['HC20'] = entero_base['HC20'].astype(str)
entero_base['SISTR1 Serovar HC20'] = entero_base['SISTR1 Serovar'] + " " + entero_base['HC20']
entero_base = entero_base.drop_duplicates(subset=['Assembly Barcode'])
entero_base = entero_base[entero_base['SISTR1 Serovar HC20'].isin(list(gen_de_importancia.index))]
entero_base = entero_base.sort_values(by='SISTR1 Serovar HC20')

plt.figure(figsize=(8, 4))
entero_base = entero_base[entero_base['SISTR1 Serovar'].isin(SEROTIPOS)]
sns.histplot(entero_base['SISTR1 Serovar HC20'], color='skyblue')

plt.title(f'Conteo assemblies unicos por SIStr1 Serovar {HC}')
plt.ylabel('Conteo', fontsize=12)
plt.xticks(rotation=45, ha='right')

plt.tight_layout()
save = os.path.join(f"histograma_{HC}_de_importancia_con_al_menos_un_AMR.png")
plt.savefig(save, format='png')
plt.show()

# %%
"""
Mapa de calor, porcentaje AMR en cluster HC de importancia
"""
HC = 'HC20'
amr_de_importancia_filtrado = amr_de_importancia_todos_genomas[amr_de_importancia_todos_genomas['SISTR1 Serovar'].isin(SEROTIPOS)]
arm_matrix_todos_los_genomas = make_matrix(amr_de_importancia_filtrado, HC)
divisors = entero_base_count['Counts'].replace(0, np.nan)
arm_matrix_todos_los_genomas = arm_matrix_todos_los_genomas.div(divisors, axis=0)
arm_matrix_todos_los_genomas_final = arm_matrix_todos_los_genomas.fillna(0)
arm_matrix_filtrado = arm_matrix_todos_los_genomas_final.loc[~(arm_matrix_todos_los_genomas_final==0).all(axis=1)]

counts = arm_matrix_filtrado.mul(divisors, axis=0)
counts = counts.fillna(0)
counts = counts.loc[~(counts==0).all(axis=1)]
counts = counts.astype(int)

heat_map = arm_matrix_filtrado.apply(lambda x: (x * 100).astype(int), axis=1)
plt.figure(figsize=(14, 8))
ax = sns.heatmap(heat_map, cmap=sns.cubehelix_palette(as_cmap=True), cbar=False, linecolor='#d5fcd4', square=True, annot=counts, fmt="d", annot_kws={"size": 8})

plt.xticks(rotation=45, ha='right')
plt.title(f'AMR presence-absence matrix by SISTR1 Serovar {HC}')
plt.xlabel('Genes and Mutations')
plt.ylabel(f'SISTR1 Serovar {HC}')

plt.tight_layout()
#plt.savefig(f'heatmap_conteo_{HC}_de_importancia_con_al_menos_un_AMR.png', format='png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Todos los genomas

# %%
"""
Filtros: amr solo de familias de importancia
"""
FAMILIAS = ['QUINOLONE', 'BETA-LACTAM', 'MACROLIDE', 'TRIMETHOPRIM']
amr_de_importancia = amr[amr['Class'].isin(FAMILIAS)]
amr_de_importancia_todos_genomas = amr_de_importancia.sort_values(by='SISTR1 Serovar HC20')
print(f"Total AMR relevantes: {amr_de_importancia_todos_genomas.shape[0]}")
amr_de_importancia_todos_genomas
# Out:
# Total AMR relevantes: 598
#                  Resistance gene         Class SISTR1 Serovar    HC20  HC50  \
# Assembly Barcode
# SAL_AD8849AA_AS         blaTEM-1   BETA-LACTAM       Adelaide  302263  2895
# SAL_AD8849AA_AS           dfrA12  TRIMETHOPRIM       Adelaide  302263  2895
# SAL_QD2199AA_AS         blaTEM-1   BETA-LACTAM          Agona     419    29
# SAL_QD2199AA_AS            qnrS1     QUINOLONE          Agona     419    29
# SAL_ZC7016AA_AS           dfrA17  TRIMETHOPRIM          Agona     419    29
# ...                          ...           ...            ...     ...   ...
# SAL_VB2133AA_AS            dfrA8  TRIMETHOPRIM    Typhimurium   74597   158
# SAL_VB2133AA_AS         blaTEM-1   BETA-LACTAM    Typhimurium   74597   158
# SAL_FB0401AA_AS            dfrA8  TRIMETHOPRIM    Typhimurium     777   158
# SAL_FB0401AA_AS         blaTEM-1   BETA-LACTAM    Typhimurium     777   158
# SAL_DC9664AA_AS             qnrB     QUINOLONE    Worthington  147475    35
#
#                       Source Niche  Collection Year SISTR1 Serovar HC20  \
# Assembly Barcode
# SAL_AD8849AA_AS        Environment             2022     Adelaide 302263
# SAL_AD8849AA_AS        Environment             2022     Adelaide 302263
# SAL_QD2199AA_AS        Environment             2022           Agona 419
# SAL_QD2199AA_AS        Environment             2022           Agona 419
# SAL_ZC7016AA_AS   Companion Animal             2021           Agona 419
# ...                            ...              ...                 ...
# SAL_VB2133AA_AS        Environment             2019   Typhimurium 74597
# SAL_VB2133AA_AS        Environment             2019   Typhimurium 74597
# SAL_FB0401AA_AS        Environment             2013     Typhimurium 777
# SAL_FB0401AA_AS        Environment             2013     Typhimurium 777
# SAL_DC9664AA_AS        Environment             2019  Worthington 147475
#
#                  SISTR1 Serovar HC50
# Assembly Barcode
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_AD8849AA_AS        Adelaide 2895
# SAL_QD2199AA_AS             Agona 29
# SAL_QD2199AA_AS             Agona 29
# SAL_ZC7016AA_AS             Agona 29
# ...                              ...
# SAL_VB2133AA_AS      Typhimurium 158
# SAL_VB2133AA_AS      Typhimurium 158
# SAL_FB0401AA_AS      Typhimurium 158
# SAL_FB0401AA_AS      Typhimurium 158
# SAL_DC9664AA_AS       Worthington 35
#
# [598 rows x 9 columns]

# %%
entero_base = pd.read_csv(os.path.join("out", "Salmonella_Chile_201124_filt.tsv"), sep='\t')

entero_base['HC20'] = entero_base['HC20'].astype(str)
entero_base['SISTR1 Serovar HC20'] = entero_base['SISTR1 Serovar'] + " " + entero_base['HC20']
# Cuento los genomas del HC
entero_base = entero_base['SISTR1 Serovar HC20'].value_counts().reset_index()
entero_base = entero_base.rename(columns={'SISTR1 Serovar HC20': 'Counts', 'index': 'SISTR1 Serovar HC20'})
entero_base.to_csv("out/entero_base_count.tsv", index=False, sep='\t')
entero_base_count = entero_base.set_index('SISTR1 Serovar HC20')
entero_base_count
# Out:
#                                                     Counts
# SISTR1 Serovar HC20
# Infantis 343                                           197
# Enteritidis 760                                         54
# Typhimurium 777                                         26
# Infantis 775                                            19
# Agona 419                                               18
# ...                                                    ...
# IIIb K:i:z 315449                                        1
# IIIb 35:i:z|IIIb 53:i:z|IIIb 57:i:z|IIIb 59:i:z...       1
# Tennessee 327751                                         1
# Anatum 34548                                             1
# Panama 478712                                            1
#
# [327 rows x 1 columns]

# %%
"""
Mapa de calor, conteo AMR en cluster HC
"""
HC = 'HC20'

FAMILIAS = ['QUINOLONE', 'BETA-LACTAM', 'MACROLIDE', 'TRIMETHOPRIM']
#amr_de_importancia = amr[amr['Class'].isin(FAMILIAS)]
amr_de_importancia_filtrado = amr_de_importancia_todos_genomas[amr_de_importancia_todos_genomas['Class'].isin(FAMILIAS)]
clusters_importancia_para_el_count = amr_de_importancia_filtrado
arm_matrix_todos_los_genomas = make_matrix(amr_de_importancia_filtrado, HC)
divisors = entero_base_count['Counts'].replace(0, np.nan)
arm_matrix_todos_los_genomas = arm_matrix_todos_los_genomas.div(divisors, axis=0)
arm_matrix_todos_los_genomas_final = arm_matrix_todos_los_genomas.fillna(0)
arm_matrix_todos_los_genomas_final
arm_matrix_filtrado = arm_matrix_todos_los_genomas_final.loc[~(arm_matrix_todos_los_genomas_final==0).all(axis=1)]
#arm_matrix_filtrado
heat_map = arm_matrix_filtrado.apply(lambda x: (x * 100).astype(int), axis=1)
heat_map
plt.figure(figsize=(16, 14))
ax = sns.heatmap(heat_map, cmap=sns.cubehelix_palette(as_cmap=True), cbar=False, linecolor='#d5fcd4', square=True, annot=heat_map, fmt="d", annot_kws={"size": 8})

plt.xticks(rotation=45, ha='right')
plt.title(f'AMR presence-absence matrix by SISTR1 Serovar {HC}')
plt.xlabel('Genes and Mutations')
plt.ylabel(f'SISTR1 Serovar {HC}')

plt.tight_layout()
#plt.savefig(f'heatmap_porcentaje_{HC}_genomas_con_al_menos_un_AMR.png', format='png', bbox_inches='tight')
plt.show()

# %%
entero_base = pd.read_csv(os.path.join("out", "Salmonella_Chile_201124_filt.tsv"), sep='\t')

entero_base['HC20'] = entero_base['HC20'].astype(str)
entero_base['SISTR1 Serovar HC20'] = entero_base['SISTR1 Serovar'] + " " + entero_base['HC20']
# Cuento los genomas del HC
entero_base = entero_base['SISTR1 Serovar HC20'].value_counts().reset_index()
entero_base = entero_base.rename(columns={'SISTR1 Serovar HC20': 'Counts', 'index': 'SISTR1 Serovar HC20'})
entero_base.to_csv("out/entero_base_count.tsv", index=False, sep='\t')
entero_base_count = entero_base.set_index('SISTR1 Serovar HC20')
entero_base_count = entero_base[entero_base['SISTR1 Serovar HC20'].isin(list(clusters_importancia_para_el_count.index))]
entero_base_count = entero_base_count.sort_values(by='SISTR1 Serovar HC20')
entero_base_count

list(clusters_importancia_para_el_count.index)
# Out:
# ['SAL_AD8849AA_AS',
#  'SAL_AD8849AA_AS',
#  'SAL_QD2199AA_AS',
#  'SAL_QD2199AA_AS',
#  'SAL_ZC7016AA_AS',
#  'SAL_JC3732AA_AS',
#  'SAL_DC0057AA_AS',
#  'SAL_JC3732AA_AS',
#  'SAL_DC0057AA_AS',
#  'SAL_PD3883AA_AS',
#  'SAL_YC3231AA_AS',
#  'SAL_TC9673AA_AS',
#  'SAL_FB0409AA_AS',
#  'SAL_VB0071AA_AS',
#  'SAL_AD8864AA_AS',
#  'SAL_TC9676AA_AS',
#  'SAL_VB2035AA_AS',
#  'SAL_YC3142AA_AS',
#  'SAL_YC3142AA_AS',
#  'SAL_YC3142AA_AS',
#  'SAL_TC9627AA_AS',
#  'SAL_MB2491AA_AS',
#  'SAL_PD2976AA_AS',
#  'SAL_AD9205AA_AS',
#  'SAL_DC0023AA_AS',
#  'SAL_XC6776AA_AS',
#  'SAL_XC6776AA_AS',
#  'SAL_PD2829AA_AS',
#  'SAL_PD2829AA_AS',
#  'SAL_YC2751AA_AS',
#  'SAL_GD2457AA_AS',
#  'SAL_GD2457AA_AS',
#  'SAL_IA5218AA_AS',
#  'SAL_UC6674AA_AS',
#  'SAL_PD2922AA_AS',
#  'SAL_TC9670AA_AS',
#  'SAL_PD2922AA_AS',
#  'SAL_TC9670AA_AS',
#  'SAL_TC9670AA_AS',
#  'SAL_PD2922AA_AS',
#  'SAL_KA9471AA_AS',
#  'SAL_QD2214AA_AS',
#  'SAL_YC3235AA_AS',
#  'SAL_KA9472AA_AS',
#  'SAL_IC2173AA_AS',
#  'SAL_BC5935AA_AS',
#  'SAL_DC1809AA_AS',
#  'SAL_DC1803AA_AS',
#  'SAL_IC2190AA_AS',
#  'SAL_DC1810AA_AS',
#  'SAL_FB0412AA_AS',
#  'SAL_BC4448AA_AS',
#  'SAL_YC0830AA_AS',
#  'SAL_TC9734AA_AS',
#  'SAL_YC2677AA_AS',
#  'SAL_YC2677AA_AS',
#  'SAL_HD4906AA_AS',
#  'SAL_XC1786AA_AS',
#  'SAL_XC1786AA_AS',
#  'SAL_PD2833AA_AS',
#  'SAL_PD2833AA_AS',
#  'SAL_KD2112AA_AS',
#  'SAL_KD2110AA_AS',
#  'SAL_KD2110AA_AS',
#  'SAL_KD2092AA_AS',
#  'SAL_KD2094AA_AS',
#  'SAL_KD2114AA_AS',
#  'SAL_KD2117AA_AS',
#  'SAL_HD4925AA_AS',
#  'SAL_HD4925AA_AS',
#  'SAL_KD2091AA_AS',
#  'SAL_KD2114AA_AS',
#  'SAL_KD2117AA_AS',
#  'SAL_KD2094AA_AS',
#  'SAL_HD4925AA_AS',
#  'SAL_KD2103AA_AS',
#  'SAL_KD2101AA_AS',
#  'SAL_KD2101AA_AS',
#  'SAL_KD2103AA_AS',
#  'SAL_KD2105AA_AS',
#  'SAL_KD2100AA_AS',
#  'SAL_KD2100AA_AS',
#  'SAL_KD2109AA_AS',
#  'SAL_KD2114AA_AS',
#  'SAL_KD2094AA_AS',
#  'SAL_KD2097AA_AS',
#  'SAL_KD2109AA_AS',
#  'SAL_KD2104AA_AS',
#  'SAL_AD1424AA_AS',
#  'SAL_AD1422AA_AS',
#  'SAL_KD2097AA_AS',
#  'SAL_KD2107AA_AS',
#  'SAL_KD2097AA_AS',
#  'SAL_KD2101AA_AS',
#  'SAL_AD9524AA_AS',
#  'SAL_AD1423AA_AS',
#  'SAL_KD2105AA_AS',
#  'SAL_KD2105AA_AS',
#  'SAL_KD2095AA_AS',
#  'SAL_KD2108AA_AS',
#  'SAL_KD2095AA_AS',
#  'SAL_KD2095AA_AS',
#  'SAL_AD8933AA_AS',
#  'SAL_AD8922AA_AS',
#  'SAL_AD8922AA_AS',
#  'SAL_AD1423AA_AS',
#  'SAL_AD1425AA_AS',
#  'SAL_AD1425AA_AS',
#  'SAL_AD1425AA_AS',
#  'SAL_AD8933AA_AS',
#  'SAL_AD1424AA_AS',
#  'SAL_AD1422AA_AS',
#  'SAL_AD1424AA_AS',
#  'SAL_AD1422AA_AS',
#  'SAL_AD1420AA_AS',
#  'SAL_AD1420AA_AS',
#  'SAL_KD2104AA_AS',
#  'SAL_AD0142AA_AS',
#  'SAL_AD9521AA_AS',
#  'SAL_AD1419AA_AS',
#  'SAL_AD1419AA_AS',
#  'SAL_AD0145AA_AS',
#  'SAL_AD1423AA_AS',
#  'SAL_AD1420AA_AS',
#  'SAL_AD0145AA_AS',
#  'SAL_AD0145AA_AS',
#  'SAL_AD0127AA_AS',
#  'SAL_AD0144AA_AS',
#  'SAL_AD0144AA_AS',
#  'SAL_AD1419AA_AS',
#  'SAL_AD9520AA_AS',
#  'SAL_AD9520AA_AS',
#  'SAL_AD9520AA_AS',
#  'SAL_AD9520AA_AS',
#  'SAL_AD9521AA_AS',
#  'SAL_AD9523AA_AS',
#  'SAL_AD9523AA_AS',
#  'SAL_AD1418AA_AS',
#  'SAL_AD1418AA_AS',
#  'SAL_AD1418AA_AS',
#  'SAL_AD1417AA_AS',
#  'SAL_AD1417AA_AS',
#  'SAL_AD8933AA_AS',
#  'SAL_PD2915AA_AS',
#  'SAL_AD0127AA_AS',
#  'SAL_KD2104AA_AS',
#  'SAL_KD2107AA_AS',
#  'SAL_AD9518AA_AS',
#  'SAL_AD9521AA_AS',
#  'SAL_AD9515AA_AS',
#  'SAL_AD9515AA_AS',
#  'SAL_AD9515AA_AS',
#  'SAL_AD9514AA_AS',
#  'SAL_AD9515AA_AS',
#  'SAL_AD9514AA_AS',
#  'SAL_AD9524AA_AS',
#  'SAL_HD4896AA_AS',
#  'SAL_HD4892AA_AS',
#  'SAL_HD4892AA_AS',
#  'SAL_HD4892AA_AS',
#  'SAL_AD9524AA_AS',
#  'SAL_GD2468AA_AS',
#  'SAL_BD3939AA_AS',
#  'SAL_BD3939AA_AS',
#  'SAL_HD4896AA_AS',
#  'SAL_AD9516AA_AS',
#  'SAL_AD9516AA_AS',
#  'SAL_AD9517AA_AS',
#  'SAL_KD2117AA_AS',
#  'SAL_AD9517AA_AS',
#  'SAL_AD9081AA_AS',
#  'SAL_AD9081AA_AS',
#  'SAL_AD9514AA_AS',
#  'SAL_AD9518AA_AS',
#  'SAL_PD4275AA_AS',
#  'SAL_PD3947AA_AS',
#  'SAL_OD3330AA_AS',
#  'SAL_QD2120AA_AS',
#  'SAL_QD2120AA_AS',
#  'SAL_QD2296AA_AS',
#  'SAL_QD2075AA_AS',
#  'SAL_QD2123AA_AS',
#  'SAL_PD4231AA_AS',
#  'SAL_PD4225AA_AS',
#  'SAL_PD4225AA_AS',
#  'SAL_PD4231AA_AS',
#  'SAL_PD4225AA_AS',
#  'SAL_QD2075AA_AS',
#  'SAL_PD4090AA_AS',
#  'SAL_PD4213AA_AS',
#  'SAL_PD4213AA_AS',
#  'SAL_PD4213AA_AS',
#  'SAL_PD4146AA_AS',
#  'SAL_PD4143AA_AS',
#  'SAL_PD4143AA_AS',
#  'SAL_PD4143AA_AS',
#  'SAL_PD4085AA_AS',
#  'SAL_PD4085AA_AS',
#  'SAL_PD4085AA_AS',
#  'SAL_PD4052AA_AS',
#  'SAL_PD4131AA_AS',
#  'SAL_PD3972AA_AS',
#  'SAL_QD2123AA_AS',
#  'SAL_PD3972AA_AS',
#  'SAL_QD2123AA_AS',
#  'SAL_QD2869AA_AS',
#  'SAL_RD3121AA_AS',
#  'SAL_RD3115AA_AS',
#  'SAL_RD3107AA_AS',
#  'SAL_RD3111AA_AS',
#  'SAL_RD3105AA_AS',
#  'SAL_RD3109AA_AS',
#  'SAL_RD3109AA_AS',
#  'SAL_RD3109AA_AS',
#  'SAL_RD3107AA_AS',
#  'SAL_RD3107AA_AS',
#  'SAL_RD3111AA_AS',
#  'SAL_RD3106AA_AS',
#  'SAL_RD3111AA_AS',
#  'SAL_RD1770AA_AS',
#  'SAL_QD2447AA_AS',
#  'SAL_QD2870AA_AS',
#  'SAL_RD1770AA_AS',
#  'SAL_RD1770AA_AS',
#  'SAL_QD2304AA_AS',
#  'SAL_QD2882AA_AS',
#  'SAL_QD2304AA_AS',
#  'SAL_QD2869AA_AS',
#  'SAL_RD3114AA_AS',
#  'SAL_RD3105AA_AS',
#  'SAL_QD2870AA_AS',
#  'SAL_QD2447AA_AS',
#  'SAL_PD4052AA_AS',
#  'SAL_PD4131AA_AS',
#  'SAL_QD2879AA_AS',
#  'SAL_PD2827AA_AS',
#  'SAL_OD3631AA_AS',
#  'SAL_OD3631AA_AS',
#  'SAL_PD2856AA_AS',
#  'SAL_PD2889AA_AS',
#  'SAL_PD2889AA_AS',
#  'SAL_PD2869AA_AS',
#  'SAL_OD3629AA_AS',
#  'SAL_QD2878AA_AS',
#  'SAL_PD3971AA_AS',
#  'SAL_PD3971AA_AS',
#  'SAL_PD2851AA_AS',
#  'SAL_PD2852AA_AS',
#  'SAL_PD2851AA_AS',
#  'SAL_PD2869AA_AS',
#  'SAL_KD8015AA_AS',
#  'SAL_KD8015AA_AS',
#  'SAL_KD8015AA_AS',
#  'SAL_OD3631AA_AS',
#  'SAL_OD3629AA_AS',
#  'SAL_KD8016AA_AS',
#  'SAL_PD2859AA_AS',
#  'SAL_PD2859AA_AS',
#  'SAL_OD3341AA_AS',
#  'SAL_OD3330AA_AS',
#  'SAL_PD3856AA_AS',
#  'SAL_PD3941AA_AS',
#  'SAL_PD3941AA_AS',
#  'SAL_ZC9426AA_AS',
#  'SAL_PD3886AA_AS',
#  'SAL_PD3886AA_AS',
#  'SAL_PD3896AA_AS',
#  'SAL_PD3859AA_AS',
#  'SAL_PD3859AA_AS',
#  'SAL_PD3856AA_AS',
#  'SAL_PD3971AA_AS',
#  'SAL_OD3627AA_AS',
#  'SAL_OD3627AA_AS',
#  'SAL_OD3341AA_AS',
#  'SAL_OD3341AA_AS',
#  'SAL_PD4275AA_AS',
#  'SAL_PD4275AA_AS',
#  'SAL_PD2914AA_AS',
#  'SAL_PD2914AA_AS',
#  'SAL_PD3896AA_AS',
#  'SAL_PD3896AA_AS',
#  'SAL_PD2923AA_AS',
#  'SAL_PD2923AA_AS',
#  'SAL_PD2923AA_AS',
#  'SAL_PD2915AA_AS',
#  'SAL_PD2915AA_AS',
#  'SAL_PD3947AA_AS',
#  'SAL_PD3957AA_AS',
#  'SAL_PD3957AA_AS',
#  'SAL_PD3957AA_AS',
#  'SAL_PD2914AA_AS',
#  'SAL_AD0118AA_AS',
#  'SAL_AD1417AA_AS',
#  'SAL_AD0104AA_AS',
#  'SAL_TC9635AA_AS',
#  'SAL_TC9626AA_AS',
#  'SAL_TC9626AA_AS',
#  'SAL_TC9626AA_AS',
#  'SAL_PD2926AA_AS',
#  'SAL_AD0118AA_AS',
#  'SAL_PD2984AA_AS',
#  'SAL_PD2984AA_AS',
#  'SAL_PD2979AA_AS',
#  'SAL_PD2926AA_AS',
#  'SAL_PD2979AA_AS',
#  'SAL_PD2979AA_AS',
#  'SAL_PD2926AA_AS',
#  'SAL_IC2166AA_AS',
#  'SAL_IC2168AA_AS',
#  'SAL_IC2168AA_AS',
#  'SAL_IC2168AA_AS',
#  'SAL_TC9791AA_AS',
#  'SAL_IC2177AA_AS',
#  'SAL_IC2177AA_AS',
#  'SAL_VB2034AA_AS',
#  'SAL_TC9759AA_AS',
#  'SAL_TC9759AA_AS',
#  'SAL_TC9791AA_AS',
#  'SAL_TC9791AA_AS',
#  'SAL_TC9743AA_AS',
#  'SAL_TC9755AA_AS',
#  'SAL_RD3120AA_AS',
#  'SAL_IC2166AA_AS',
#  'SAL_XC1790AA_AS',
#  'SAL_XC1822AA_AS',
#  'SAL_BD3881AA_AS',
#  'SAL_XC1790AA_AS',
#  'SAL_YC3193AA_AS',
#  'SAL_YC3193AA_AS',
#  'SAL_YC3193AA_AS',
#  'SAL_JC3740AA_AS',
#  'SAL_JC3740AA_AS',
#  'SAL_IC2156AA_AS',
#  'SAL_IC2156AA_AS',
#  'SAL_IC2156AA_AS',
#  'SAL_IC2166AA_AS',
#  'SAL_TC9823AA_AS',
#  'SAL_TC9823AA_AS',
#  'SAL_TC9823AA_AS',
#  'SAL_TC9782AA_AS',
#  'SAL_TC9782AA_AS',
#  'SAL_TC9782AA_AS',
#  'SAL_XC8298AA_AS',
#  'SAL_XC8298AA_AS',
#  'SAL_XC1842AA_AS',
#  'SAL_XC1822AA_AS',
#  'SAL_XC1822AA_AS',
#  'SAL_XC1842AA_AS',
#  'SAL_TC9635AA_AS',
#  'SAL_TC9759AA_AS',
#  'SAL_TC9755AA_AS',
#  'SAL_XC2731AA_AS',
#  'SAL_IC2184AA_AS',
#  'SAL_HB4512AA_AS',
#  'SAL_HB4512AA_AS',
#  'SAL_YC3091AA_AS',
#  'SAL_XC1554AA_AS',
#  'SAL_XC1554AA_AS',
#  'SAL_XC2731AA_AS',
#  'SAL_YC2738AA_AS',
#  'SAL_XC2731AA_AS',
#  'SAL_HB5941AA_AS',
#  'SAL_VB2057AA_AS',
#  'SAL_HB4594AA_AS',
#  'SAL_HB4594AA_AS',
#  'SAL_HB4594AA_AS',
#  'SAL_BB2263AA_AS',
#  'SAL_BB2263AA_AS',
#  'SAL_BB2263AA_AS',
#  'SAL_VB2097AA_AS',
#  'SAL_HB4512AA_AS',
#  'SAL_HB9648AA_AS',
#  'SAL_HB9648AA_AS',
#  'SAL_HB5959AA_AS',
#  'SAL_HB5959AA_AS',
#  'SAL_HB5959AA_AS',
#  'SAL_HB9648AA_AS',
#  'SAL_HB5941AA_AS',
#  'SAL_HB9484AA_AS',
#  'SAL_HB9484AA_AS',
#  'SAL_DC1804AA_AS',
#  'SAL_IC2191AA_AS',
#  'SAL_DC9651AA_AS',
#  'SAL_DC9651AA_AS',
#  'SAL_DC9651AA_AS',
#  'SAL_DC1804AA_AS',
#  'SAL_HB4545AA_AS',
#  'SAL_HB4593AA_AS',
#  'SAL_HB4593AA_AS',
#  'SAL_HB4593AA_AS',
#  'SAL_HB4498AA_AS',
#  'SAL_HB4545AA_AS',
#  'SAL_HB4545AA_AS',
#  'SAL_ZC9426AA_AS',
#  'SAL_XC8298AA_AS',
#  'SAL_HB4498AA_AS',
#  'SAL_VB2046AA_AS',
#  'SAL_VB2046AA_AS',
#  'SAL_VB2072AA_AS',
#  'SAL_VB2072AA_AS',
#  'SAL_VB2072AA_AS',
#  'SAL_IC2184AA_AS',
#  'SAL_IC2182AA_AS',
#  'SAL_IC2182AA_AS',
#  'SAL_IC2185AA_AS',
#  'SAL_IC2185AA_AS',
#  'SAL_DC1804AA_AS',
#  'SAL_IC2184AA_AS',
#  'SAL_ZC7018AA_AS',
#  'SAL_TC9743AA_AS',
#  'SAL_ZC7013AA_AS',
#  'SAL_AD0095AA_AS',
#  'SAL_AD0095AA_AS',
#  'SAL_ZC9430AA_AS',
#  'SAL_AD0095AA_AS',
#  'SAL_ZC9429AA_AS',
#  'SAL_ZC9429AA_AS',
#  'SAL_ZC9429AA_AS',
#  'SAL_DC1805AA_AS',
#  'SAL_DC1805AA_AS',
#  'SAL_DC1805AA_AS',
#  'SAL_DC1808AA_AS',
#  'SAL_DC1808AA_AS',
#  'SAL_DC1808AA_AS',
#  'SAL_ZC9430AA_AS',
#  'SAL_ZC9421AA_AS',
#  'SAL_ZC9422AA_AS',
#  'SAL_ZC9422AA_AS',
#  'SAL_ZC9421AA_AS',
#  'SAL_ZC9421AA_AS',
#  'SAL_AD0096AA_AS',
#  'SAL_AD0098AA_AS',
#  'SAL_AD0098AA_AS',
#  'SAL_AD0118AA_AS',
#  'SAL_AD0142AA_AS',
#  'SAL_AD0097AA_AS',
#  'SAL_AD0101AA_AS',
#  'SAL_AD0097AA_AS',
#  'SAL_ZC9420AA_AS',
#  'SAL_AD0108AA_AS',
#  'SAL_AD0104AA_AS',
#  'SAL_AD0103AA_AS',
#  'SAL_AD0103AA_AS',
#  'SAL_ZC9422AA_AS',
#  'SAL_ZC9423AA_AS',
#  'SAL_ZC9423AA_AS',
#  'SAL_ZC9428AA_AS',
#  'SAL_ZC9428AA_AS',
#  'SAL_ZC9427AA_AS',
#  'SAL_ZC9426AA_AS',
#  'SAL_ZC9420AA_AS',
#  'SAL_AD0107AA_AS',
#  'SAL_AD0105AA_AS',
#  'SAL_AD0105AA_AS',
#  'SAL_AD0101AA_AS',
#  'SAL_AD0100AA_AS',
#  'SAL_AD0100AA_AS',
#  'SAL_AD0107AA_AS',
#  'SAL_AD0117AA_AS',
#  'SAL_ZC7013AA_AS',
#  'SAL_AD0102AA_AS',
#  'SAL_AD0103AA_AS',
#  'SAL_AD0104AA_AS',
#  'SAL_AD0110AA_AS',
#  'SAL_AD0110AA_AS',
#  'SAL_AD0108AA_AS',
#  'SAL_AD0097AA_AS',
#  'SAL_AD0102AA_AS',
#  'SAL_AD0100AA_AS',
#  'SAL_ZC9414AA_AS',
#  'SAL_ZC7003AA_AS',
#  'SAL_AD0121AA_AS',
#  'SAL_AD0121AA_AS',
#  'SAL_AD0114AA_AS',
#  'SAL_AD0102AA_AS',
#  'SAL_ZC9420AA_AS',
#  'SAL_ZC7012AA_AS',
#  'SAL_AD0121AA_AS',
#  'SAL_AD0098AA_AS',
#  'SAL_AD0101AA_AS',
#  'SAL_ZC9411AA_AS',
#  'SAL_AD0117AA_AS',
#  'SAL_ZC7011AA_AS',
#  'SAL_ZC7011AA_AS',
#  'SAL_ZC7011AA_AS',
#  'SAL_ZC7008AA_AS',
#  'SAL_ZC7004AA_AS',
#  'SAL_ZC7018AA_AS',
#  'SAL_ZC7012AA_AS',
#  'SAL_ZC7010AA_AS',
#  'SAL_ZC7010AA_AS',
#  'SAL_ZC7009AA_AS',
#  'SAL_ZC7008AA_AS',
#  'SAL_AD0117AA_AS',
#  'SAL_ZC9419AA_AS',
#  'SAL_ZC7003AA_AS',
#  'SAL_ZC9412AA_AS',
#  'SAL_ZC7005AA_AS',
#  'SAL_ZC7006AA_AS',
#  'SAL_ZC7005AA_AS',
#  'SAL_ZC7006AA_AS',
#  'SAL_ZC7006AA_AS',
#  'SAL_ZC9413AA_AS',
#  'SAL_ZC9414AA_AS',
#  'SAL_ZC9413AA_AS',
#  'SAL_ZC9412AA_AS',
#  'SAL_ZC7002AA_AS',
#  'SAL_ZC7002AA_AS',
#  'SAL_ZC7004AA_AS',
#  'SAL_ZC7007AA_AS',
#  'SAL_ZC7002AA_AS',
#  'SAL_ZC9419AA_AS',
#  'SAL_ZC9414AA_AS',
#  'SAL_ZC9415AA_AS',
#  'SAL_ZC7007AA_AS',
#  'SAL_ZC9415AA_AS',
#  'SAL_ZC9415AA_AS',
#  'SAL_ZC9413AA_AS',
#  'SAL_ZC9411AA_AS',
#  'SAL_ZC9412AA_AS',
#  'SAL_AD0096AA_AS',
#  'SAL_PD4255AA_AS',
#  'SAL_PD4255AA_AS',
#  'SAL_PD4255AA_AS',
#  'SAL_XC1236AA_AS',
#  'SAL_WC7177AA_AS',
#  'SAL_PD2850AA_AS',
#  'SAL_PD3898AA_AS',
#  'SAL_YC3069AA_AS',
#  'SAL_VC0878AA_AS',
#  'SAL_UC6694AA_AS',
#  'SAL_DC0047AA_AS',
#  'SAL_XC1791AA_AS',
#  'SAL_XC2728AA_AS',
#  'SAL_VB0505AA_AS',
#  'SAL_BC5933AA_AS',
#  'SAL_BC5933AA_AS',
#  'SAL_DC1800AA_AS',
#  'SAL_DC1812AA_AS',
#  'SAL_DC1812AA_AS',
#  'SAL_DC1812AA_AS',
#  'SAL_DC1812AA_AS',
#  'SAL_DC1800AA_AS',
#  'SAL_HD4916AA_AS',
#  'SAL_HD4916AA_AS',
#  'SAL_HD4902AA_AS',
#  'SAL_HD4902AA_AS',
#  'SAL_HD4916AA_AS',
#  'SAL_HD4902AA_AS',
#  'SAL_QD2283AA_AS',
#  'SAL_QD2283AA_AS',
#  'SAL_YC2680AA_AS',
#  'SAL_YC2680AA_AS',
#  'SAL_YC2680AA_AS',
#  'SAL_YC2680AA_AS',
#  'SAL_QD2283AA_AS',
#  'SAL_QD2283AA_AS',
#  'SAL_RD3113AA_AS',
#  'SAL_RD3113AA_AS',
#  'SAL_DC0013AA_AS',
#  'SAL_PD2906AA_AS',
#  'SAL_PD2906AA_AS',
#  'SAL_PD2906AA_AS',
#  'SAL_PD2906AA_AS',
#  'SAL_AC6595AA_AS',
#  'SAL_FB0428AA_AS',
#  'SAL_HB4514AA_AS',
#  'SAL_HC9298AA_AS',
#  'SAL_PD2947AA_AS',
#  'SAL_IC2179AA_AS',
#  'SAL_AC6600AA_AS',
#  'SAL_AD8885AA_AS',
#  'SAL_TC9684AA_AS',
#  'SAL_AD8845AA_AS',
#  'SAL_AC6600AA_AS',
#  'SAL_AD8888AA_AS',
#  'SAL_IC2171AA_AS',
#  'SAL_VB2095AA_AS',
#  'SAL_PD3904AA_AS',
#  'SAL_VB2095AA_AS',
#  'SAL_PD3904AA_AS',
#  'SAL_OC0804AA_AS',
#  'SAL_IA5729AA_AS',
#  'SAL_MB2490AA_AS',
#  'SAL_MB2476AA_AS',
#  'SAL_MB2470AA_AS',
#  'SAL_PD4169AA_AS',
#  'SAL_IA5729AA_AS',
#  'SAL_DC0019AA_AS',
#  'SAL_WC7180AA_AS',
#  'SAL_WC7180AA_AS',
#  'SAL_WC7180AA_AS',
#  'SAL_QD6445AA_AS',
#  'SAL_VB2133AA_AS',
#  'SAL_VB2133AA_AS',
#  'SAL_FB0401AA_AS',
#  'SAL_FB0401AA_AS',
#  'SAL_DC9664AA_AS']

# %%
"""
Mapa de calor, conteo AMR en cluster HC
"""
HC = 'HC20'

FAMILIAS = ['QUINOLONE', 'BETA-LACTAM', 'MACROLIDE', 'TRIMETHOPRIM']
#amr_de_importancia = amr[amr['Class'].isin(FAMILIAS)]
amr_de_importancia_filtrado = amr_de_importancia_todos_genomas[amr_de_importancia_todos_genomas['Class'].isin(FAMILIAS)]

arm_matrix_todos_los_genomas = make_matrix(amr_de_importancia_filtrado, HC)
#divisors = entero_base_count['Counts'].replace(0, np.nan)
#arm_matrix_todos_los_genomas = arm_matrix_todos_los_genomas.div(divisors, axis=0)
arm_matrix_todos_los_genomas_final = arm_matrix_todos_los_genomas.fillna(0)
arm_matrix_todos_los_genomas_final
arm_matrix_filtrado = arm_matrix_todos_los_genomas_final.loc[~(arm_matrix_todos_los_genomas_final==0).all(axis=1)]
#arm_matrix_filtrado
#heat_map = arm_matrix_filtrado.apply(lambda x: (x * 100).astype(int), axis=1)
#heat_map
plt.figure(figsize=(16, 14))
ax = sns.heatmap(heat_map, cmap=sns.cubehelix_palette(as_cmap=True), cbar=False, linecolor='#d5fcd4', square=True, annot=arm_matrix_filtrado, fmt='d', annot_kws={"size": 8})

plt.xticks(rotation=45, ha='right')
plt.title(f'AMR presence-absence matrix by SISTR1 Serovar {HC}')
plt.xlabel('Genes and Mutations')
plt.ylabel(f'SISTR1 Serovar {HC}')

plt.tight_layout()
#plt.savefig(f'heatmap_conteo_{HC}_genomas_con_al_menos_un_AMR.png', format='png', bbox_inches='tight')
plt.show()
